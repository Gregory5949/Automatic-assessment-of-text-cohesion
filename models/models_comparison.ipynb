# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\john_lenin\appdata\local\programs\python\python311\lib\site-packages (24.0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\john_lenin\appdata\local\programs\python\python311\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\john_lenin\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)

# %%
from tqdm import tqdm

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.2-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\john_lenin\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.24.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\john_lenin\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.9.3)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Downloading gensim-4.3.2-cp311-cp311-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/24.0 MB 1.2 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/24.0 MB 1.3 MB/s eta 0:00:19
#    ---------------------------------------- 0.3/24.0 MB 1.6 MB/s eta 0:00:16
#     --------------------------------------- 0.4/24.0 MB 1.8 MB/s eta 0:00:14
#     --------------------------------------- 0.4/24.0 MB 1.6 MB/s eta 0:00:15
#     --------------------------------------- 0.5/24.0 MB 1.6 MB/s eta 0:00:15
#    - -------------------------------------- 0.6/24.0 MB 1.7 MB/s eta 0:00:14
#    - -------------------------------------- 0.7/24.0 MB 1.7 MB/s eta 0:00:14
#    - -------------------------------------- 0.8/24.0 MB 1.8 MB/s eta 0:00:14
#    - -------------------------------------- 0.9/24.0 MB 1.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/24.0 MB 1.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.1/24.0 MB 1.8 MB/s eta 0:00:13
#    - -------------------------------------- 1.2/24.0 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.2/24.0 MB 1.7 MB/s eta 0:00:14
#    -- ------------------------------------- 1.4/24.0 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.4/24.0 MB 1.7 MB/s eta 0:00:13
#    -- ------------------------------------- 1.5/24.0 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.6/24.0 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.7/24.0 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.8/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 1.9/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 1.9/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.0/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.1/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.2/24.0 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.3/24.0 MB 1.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.4/24.0 MB 1.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.5/24.0 MB 1.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.6/24.0 MB 1.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.7/24.0 MB 1.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.8/24.0 MB 1.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.9/24.0 MB 1.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.9/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.0/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.1/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.2/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.3/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.4/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.5/24.0 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.5/24.0 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/24.0 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/24.0 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.9/24.0 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.9/24.0 MB 1.8 MB/s eta 0:00:11
#    ------ --------------------------------- 4.0/24.0 MB 1.8 MB/s eta 0:00:11
#    ------ --------------------------------- 4.1/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.2/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.3/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.3/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.5/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.6/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.6/24.0 MB 1.8 MB/s eta 0:00:11
#    ------- -------------------------------- 4.7/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 4.8/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 4.9/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 5.0/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 5.1/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 5.2/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 5.3/24.0 MB 1.8 MB/s eta 0:00:11
#    -------- ------------------------------- 5.4/24.0 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 5.4/24.0 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 5.5/24.0 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 5.6/24.0 MB 1.8 MB/s eta 0:00:10
#    --------- ------------------------------ 5.7/24.0 MB 1.8 MB/s eta 0:00:10
#    --------- ------------------------------ 5.8/24.0 MB 1.8 MB/s eta 0:00:10
#    --------- ------------------------------ 5.9/24.0 MB 1.8 MB/s eta 0:00:10
#    --------- ------------------------------ 6.0/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.1/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.2/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.2/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.3/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.4/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.5/24.0 MB 1.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 6.6/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 6.6/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 6.8/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 6.8/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 6.9/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 7.0/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 7.1/24.0 MB 1.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 7.2/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.3/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.4/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.5/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.5/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------ --------------------------- 7.7/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------ --------------------------- 7.8/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 7.8/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 7.9/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 8.0/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 8.1/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 8.2/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 8.3/24.0 MB 1.8 MB/s eta 0:00:09
#    ------------- -------------------------- 8.4/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.4/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.5/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.6/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.7/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.8/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 8.9/24.0 MB 1.8 MB/s eta 0:00:09
#    -------------- ------------------------- 9.0/24.0 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.1/24.0 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.1/24.0 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.2/24.0 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.3/24.0 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.4/24.0 MB 1.8 MB/s eta 0:00:08
#    --------------- ------------------------ 9.5/24.0 MB 1.8 MB/s eta 0:00:08
#    --------------- ------------------------ 9.5/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 9.6/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 9.7/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 9.8/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 9.9/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 10.0/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 10.1/24.0 MB 1.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 10.2/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.3/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.3/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.4/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.5/24.0 MB 1.9 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.6/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.7/24.0 MB 1.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.8/24.0 MB 1.9 MB/s eta 0:00:08
#    ------------------ --------------------- 10.9/24.0 MB 1.9 MB/s eta 0:00:08
#    ------------------ --------------------- 11.0/24.0 MB 1.8 MB/s eta 0:00:08
#    ------------------ --------------------- 11.1/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------ --------------------- 11.2/24.0 MB 1.8 MB/s eta 0:00:07
#    ------------------ --------------------- 11.3/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------ --------------------- 11.3/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------- -------------------- 11.4/24.0 MB 1.8 MB/s eta 0:00:07
#    ------------------- -------------------- 11.5/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------- -------------------- 11.6/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------- -------------------- 11.7/24.0 MB 1.8 MB/s eta 0:00:07
#    ------------------- -------------------- 11.8/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------- -------------------- 11.9/24.0 MB 1.9 MB/s eta 0:00:07
#    ------------------- -------------------- 12.0/24.0 MB 1.8 MB/s eta 0:00:07
#    -------------------- ------------------- 12.1/24.0 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.2/24.0 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.2/24.0 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.3/24.0 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.4/24.0 MB 1.9 MB/s eta 0:00:07
#    -------------------- ------------------- 12.5/24.0 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 12.6/24.0 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 12.6/24.0 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 12.6/24.0 MB 1.9 MB/s eta 0:00:07
#    --------------------- ------------------ 12.8/24.0 MB 1.8 MB/s eta 0:00:07
#    --------------------- ------------------ 12.8/24.0 MB 1.8 MB/s eta 0:00:07
#    --------------------- ------------------ 12.9/24.0 MB 1.8 MB/s eta 0:00:07
#    --------------------- ------------------ 13.0/24.0 MB 1.8 MB/s eta 0:00:06
#    --------------------- ------------------ 13.1/24.0 MB 1.8 MB/s eta 0:00:06
#    --------------------- ------------------ 13.2/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.3/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.4/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.5/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.6/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.7/24.0 MB 1.8 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.8/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 13.8/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 13.9/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.0/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.1/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.2/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.3/24.0 MB 1.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.4/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.5/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.6/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.6/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.7/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.8/24.0 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 14.9/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.0/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.0/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.0/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.2/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.2/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.3/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.4/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.5/24.0 MB 1.8 MB/s eta 0:00:05
#    ------------------------- -------------- 15.6/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 15.7/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 15.7/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 15.9/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 15.9/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 16.0/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 16.1/24.0 MB 1.8 MB/s eta 0:00:05
#    -------------------------- ------------- 16.2/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.3/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.4/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.4/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.5/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.6/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.7/24.0 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 16.8/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 16.9/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.0/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.1/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.2/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.3/24.0 MB 1.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.4/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.4/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.5/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.6/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.7/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.8/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.9/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.9/24.0 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.9/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.0/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.1/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.1/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.2/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.3/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.3/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.4/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.5/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.5/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.6/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 18.6/24.0 MB 1.8 MB/s eta 0:00:04
#    ------------------------------- -------- 18.7/24.0 MB 1.7 MB/s eta 0:00:04
#    ------------------------------- -------- 18.7/24.0 MB 1.7 MB/s eta 0:00:04
#    ------------------------------- -------- 18.8/24.0 MB 1.7 MB/s eta 0:00:04
#    ------------------------------- -------- 18.8/24.0 MB 1.7 MB/s eta 0:00:04
#    ------------------------------- -------- 18.9/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 18.9/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 19.0/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 19.0/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 19.1/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 19.1/24.0 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 19.2/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.3/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.3/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.4/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.4/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.5/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.5/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.6/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.7/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.7/24.0 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 19.8/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 19.8/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 19.8/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 19.8/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 19.9/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.0/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.0/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.0/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.0/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.1/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.2/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.2/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.2/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.3/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.3/24.0 MB 1.6 MB/s eta 0:00:03
#    --------------------------------- ------ 20.3/24.0 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 20.4/24.0 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 20.4/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.4/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.5/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.5/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.5/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.6/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.6/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.6/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.6/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.7/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.7/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.7/24.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.8/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.8/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.8/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.8/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.9/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.9/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.9/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.9/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 21.0/24.0 MB 1.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 21.0/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.0/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.0/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.1/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.1/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.1/24.0 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.2/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.2/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.2/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.2/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.3/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.3/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.4/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.4/24.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.4/24.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.4/24.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.5/24.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.5/24.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.6/24.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.6/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.6/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.6/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.7/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.7/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.8/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.8/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.8/24.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 21.9/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 21.9/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 21.9/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.1/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.1/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.1/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.2/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.2/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.2/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.3/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.3/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.3/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.3/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.4/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.4/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.5/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.5/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.5/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.6/24.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------- -- 22.6/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.6/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.7/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.7/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.7/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.7/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.8/24.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 22.8/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.8/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.8/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.8/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 22.9/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.0/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.0/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.0/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.0/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 998.0 kB/s eta 0:00:01
#    -------------------------------------- - 23.2/24.0 MB 998.0 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 990.4 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 987.5 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 981.6 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 981.6 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 977.1 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 971.3 kB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 969.9 kB/s eta 0:00:01
#    -------------------------------------- - 23.4/24.0 MB 964.3 kB/s eta 0:00:01
#    -------------------------------------- - 23.4/24.0 MB 960.0 kB/s eta 0:00:01
#    -------------------------------------- - 23.4/24.0 MB 954.4 kB/s eta 0:00:01
#    -------------------------------------- - 23.4/24.0 MB 954.4 kB/s eta 0:00:01
#    -------------------------------------- - 23.4/24.0 MB 951.6 kB/s eta 0:00:01
#    ---------------------------------------  23.4/24.0 MB 947.5 kB/s eta 0:00:01
#    ---------------------------------------  23.4/24.0 MB 943.4 kB/s eta 0:00:01
#    ---------------------------------------  23.5/24.0 MB 940.7 kB/s eta 0:00:01
#    ---------------------------------------  23.5/24.0 MB 936.6 kB/s eta 0:00:01
#    ---------------------------------------  23.5/24.0 MB 931.2 kB/s eta 0:00:01
#    ---------------------------------------  23.5/24.0 MB 927.4 kB/s eta 0:00:01
#    ---------------------------------------  23.5/24.0 MB 926.0 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 923.4 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 918.2 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 918.2 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 911.9 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 911.9 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 904.3 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 905.5 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 901.8 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 901.8 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 895.6 kB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 893.2 kB/s eta 0:00:01
#    ---------------------------------------  23.8/24.0 MB 887.2 kB/s eta 0:00:01
#    ---------------------------------------  23.8/24.0 MB 887.1 kB/s eta 0:00:01
#    ---------------------------------------  23.8/24.0 MB 884.8 kB/s eta 0:00:01
#    ---------------------------------------  23.8/24.0 MB 881.2 kB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 876.5 kB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 875.2 kB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 872.9 kB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 871.8 kB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 869.4 kB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 866.0 kB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 864.9 kB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 864.9 kB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 857.8 kB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ------- -------------------------------- 10.2/57.0 kB ? eta -:--:--
#    ----------------------------------- ---- 51.2/57.0 kB 525.1 kB/s eta 0:00:01
#    ---------------------------------------- 57.0/57.0 kB 498.0 kB/s eta 0:00:00
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.3.2 smart-open-6.4.0

# %%
#!pip install pyarrow
#!pip install simpletransformers
# !pip install simpletransformers==0.26.0
import string
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk import word_tokenize
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: sentence_transformers in /Users/gd/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (4.36.0)
# Requirement already satisfied: tqdm in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (2.1.2)
# Requirement already satisfied: torchvision in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (0.16.2)
# Requirement already satisfied: numpy in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (1.9.3)
# Requirement already satisfied: nltk in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/gd/lib/python3.10/site-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: filelock in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.7.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.10.0)
# Requirement already satisfied: requests in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/gd/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: sympy in /Users/gd/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/gd/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/gd/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gd/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.3.23)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/gd/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/gd/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.1)
# Requirement already satisfied: click in /Users/gd/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /Users/gd/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gd/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/gd/lib/python3.10/site-packages (from torchvision->sentence_transformers) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gd/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gd/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gd/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gd/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gd/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/gd/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\John_Lenin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
#'C:\\Git\\VKR-Tech.Practice\\data\\balanced_dataset.csv'
df = pd.read_csv("/Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/data/balanced_dataset.csv")
np.random.seed(42)
msk = np.random.rand(len(df)) < 0.8
df_train = df[msk]
df_eval = df[~msk]

# %%
train_sents = []
for i in df_train.sents_l:
    train_sents.append(i)
for j in df_train.sents_r:
    train_sents.append(j)

test_sents = []
for i in df_eval.sents_l:
    test_sents.append(i)
for j in df_eval.sents_r:
    test_sents.append(j)

# %%
tagged_data = [
    TaggedDocument(words=[w.lower() for w in word_tokenize(_d) if w not in string.punctuation], tags=[str(i)]) for i, _d
    in enumerate(train_sents)]

# %%
# model50 = Doc2Vec(vector_size=50)
# model50.build_vocab(tagged_data)

# model100 = Doc2Vec(vector_size=100)
# model100.build_vocab(tagged_data)

# model150 = Doc2Vec(vector_size=150)
# model150.build_vocab(tagged_data)

# model200 = Doc2Vec(vector_size=200)
# model200.build_vocab(tagged_data)

model250 = Doc2Vec(vector_size=250)
model250.build_vocab(tagged_data)

model300 = Doc2Vec(vector_size=300)
model300.build_vocab(tagged_data)

# %%
# model50.train(tagged_data, total_examples=model50.corpus_count, epochs=model50.epochs)
# model100.train(tagged_data, total_examples=model100.corpus_count, epochs=model100.epochs)
# model150.train(tagged_data, total_examples=model150.corpus_count, epochs=model150.epochs)
# model200.train(tagged_data, total_examples=model200.corpus_count, epochs=model200.epochs)
model250.train(tagged_data, total_examples=model250.corpus_count, epochs=model250.epochs)
model300.train(tagged_data, total_examples=model300.corpus_count, epochs=model300.epochs)

# %%
# X50 = pd.concat([pd.DataFrame(model50.dv.vectors[:len(model50.dv.vectors) // 2]),
#                  pd.DataFrame(model50.dv.vectors[len(model50.dv.vectors) // 2:])], axis=1)
# X100 = pd.concat([pd.DataFrame(model100.dv.vectors[:len(model100.dv.vectors) // 2]),
#                   pd.DataFrame(model100.dv.vectors[len(model100.dv.vectors) // 2:])], axis=1)
# X150 = pd.concat([pd.DataFrame(model150.dv.vectors[:len(model150.dv.vectors) // 2]),
#                   pd.DataFrame(model150.dv.vectors[len(model150.dv.vectors) // 2:])], axis=1)
# X200 = pd.concat([pd.DataFrame(model200.dv.vectors[:len(model200.dv.vectors) // 2]),
#                   pd.DataFrame(model200.dv.vectors[len(model200.dv.vectors) // 2:])], axis=1)

# X250_train = pd.concat([pd.DataFrame(model250.dv.vectors[:len(model250.dv.vectors) // 2]),
#                   pd.DataFrame(model250.dv.vectors[len(model250.dv.vectors) // 2:])], axis=1)
# X300_train = pd.concat([pd.DataFrame(model300.dv.vectors[:len(model300.dv.vectors) // 2]),
#                   pd.DataFrame(model300.dv.vectors[len(model300.dv.vectors) // 2:])], axis=1)
y_train = df_train.score

# %%
# X50_test = []
# X100_test = []
# X150_test = []
# X200_test = []
X250_test = []
X300_test = []

for i in df_eval.sents_l:
    # X50_test.append(model50.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X100_test.append(model100.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X150_test.append(model150.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X200_test.append(model200.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    X250_test.append(model250.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    X300_test.append(model300.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))

for j in df_eval.sents_r:
    # X50_test.append(model50.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X100_test.append(model100.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X150_test.append(model150.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X200_test.append(model200.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    X250_test.append(model250.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    X300_test.append(model300.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))

# %%
# X50_test_df = pd.concat([pd.DataFrame(X50_test[:len(X50_test) // 2]),
#                  pd.DataFrame(X50_test[len(X50_test) // 2:])], axis=1)

# X100_test_df = pd.concat([pd.DataFrame(X100_test[:len(X100_test) // 2]),
#                  pd.DataFrame(X100_test[len(X100_test) // 2:])], axis=1)

# X150_test_df = pd.concat([pd.DataFrame(X150_test[:len(X150_test) // 2]),
#                  pd.DataFrame(X150_test[len(X150_test) // 2:])], axis=1)

# X200_test_df = pd.concat([pd.DataFrame(X200_test[:len(X200_test) // 2]),
#                  pd.DataFrame(X200_test[len(X200_test) // 2:])], axis=1)

# X250_test = pd.concat([pd.DataFrame(X250_test[:len(X250_test) // 2]),
#                  pd.DataFrame(X250_test[len(X250_test) // 2:])], axis=1)

# X300_test = pd.concat([pd.DataFrame(X300_test[:len(X300_test) // 2]),
#                  pd.DataFrame(X300_test[len(X300_test) // 2:])], axis=1)


y_test = df_eval.score

# %%
X250_train.columns = list(range(500))
X250_test.columns = list(range(500))

X300_train.columns = list(range(600))
X300_test.columns = list(range(600))

# %%
from sklearn.utils import all_estimators
def get_all_regressors_sklearn():
    estimators = all_estimators(type_filter='regressor')
    all_regs = []
    for name, RegClass in estimators:
        print('Appending', name)
        try:
            if name != 'QuantileRegressor' and name != 'SVR':
                reg = RegClass()
                all_regs.append(reg)
        except Exception as e:
            pass
    return all_regs
all_regs = get_all_regressors_sklearn()
# Out:
# Appending ARDRegression
# Appending AdaBoostRegressor
# Appending BaggingRegressor
# Appending BayesianRidge
# Appending CCA
# Appending DecisionTreeRegressor
# Appending DummyRegressor
# Appending ElasticNet
# Appending ElasticNetCV
# Appending ExtraTreeRegressor
# Appending ExtraTreesRegressor
# Appending GammaRegressor
# Appending GaussianProcessRegressor
# Appending GradientBoostingRegressor
# Appending HistGradientBoostingRegressor
# Appending HuberRegressor
# Appending IsotonicRegression
# Appending KNeighborsRegressor
# Appending KernelRidge
# Appending Lars
# Appending LarsCV
# Appending Lasso
# Appending LassoCV
# Appending LassoLars
# Appending LassoLarsCV
# Appending LassoLarsIC
# Appending LinearRegression
# Appending LinearSVR
# Appending MLPRegressor
# Appending MultiOutputRegressor
# Appending MultiTaskElasticNet
# Appending MultiTaskElasticNetCV
# Appending MultiTaskLasso
# Appending MultiTaskLassoCV
# Appending NuSVR
# Appending OrthogonalMatchingPursuit
# Appending OrthogonalMatchingPursuitCV
# Appending PLSCanonical
# Appending PLSRegression
# Appending PassiveAggressiveRegressor
# Appending PoissonRegressor
# Appending QuantileRegressor
# Appending RANSACRegressor
# Appending RadiusNeighborsRegressor
# Appending RandomForestRegressor
# Appending RegressorChain
# Appending Ridge
# Appending RidgeCV
# Appending SGDRegressor
# Appending SVR
# Appending StackingRegressor
# Appending TheilSenRegressor
# Appending TransformedTargetRegressor
# Appending TweedieRegressor
# Appending VotingRegressor

# %%
#на dov2vec плохие результаты
for reg in all_regs:
    try:
        reg.fit(X250_train, y_train)
        print(type(reg), reg.score(X250_test, y_test))
    except Exception:
        print(type(reg), 'no')

# %%
#nusvr, poisson - лучшие результаты
for reg in all_regs:
    try:
        reg.fit(X300_train, y_train)
        print(type(reg), reg.score(X300_test, y_test))
    except Exception:
        print(type(reg), 'no')

# %%
sentence_transformer = SentenceTransformer("DeepPavlov/rubert-base-cased")
# Out:
# 2024-03-06 11:08:00,270 : INFO : Load pretrained SentenceTransformer: DeepPavlov/rubert-base-cased
# 2024-03-06 11:08:02,409 : WARNING : No sentence-transformers model found with name /Users/gd/.cache/torch/sentence_transformers/DeepPavlov_rubert-base-cased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /Users/gd/.cache/torch/sentence_transformers/DeepPavlov_rubert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2024-03-06 11:08:04,260 : INFO : Use pytorch device: cpu

# %%
train_sents_embs = sentence_transformer.encode(train_sents)
# Out:
# Batches:   0%|          | 0/652 [00:00<?, ?it/s]

# %%
test_sents_embs = sentence_transformer.encode(test_sents)
# Out:
# Batches:   0%|          | 0/162 [00:00<?, ?it/s]

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
                 pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], axis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(test_sents_embs[:len(test_sents_embs) // 2]),
                 pd.DataFrame(test_sents_embs[len(test_sents_embs) // 2:])], axis=1)

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import LassoLarsCV
br = BayesianRidge()
lr = LassoLarsCV()

# %%
br.fit(train_sents_embs_df, df_train.score)
# Out:
# BayesianRidge()

# %%
lr.fit(train_sents_embs_df, df_train.score)
# Out:
# LassoLarsCV()

# %%
print(lr.score(test_sents_embs_df, df_eval.score))
print(br.score(test_sents_embs_df, df_eval.score))
# Out:
# 0.12301874928826873
# 0.130008759525293

# %%
print(mean_absolute_error(df_eval.score,  lr.predict(test_sents_embs_df)))
print(mean_absolute_error(df_eval.score,  br.predict(test_sents_embs_df)))

print(mean_squared_error(df_eval.score,  lr.predict(test_sents_embs_df)))
print(mean_squared_error(df_eval.score,  br.predict(test_sents_embs_df)))
# Out:
# 0.4352920554413762
# 0.4349930369753805
# 0.21924448987786882
# 0.2174969938767699

# %%
br.fit(train_sents_embs_df, df_train.score)
br.score(test_sents_embs_df, df_eval.score)

# %%
import logging
from simpletransformers.classification import ClassificationModel, ClassificationArgs
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

train_df = pd.DataFrame(df_train)
train_df.columns = ["text_a", "text_b", "labels"]

eval_df = pd.DataFrame(df_eval)
eval_df.columns = ["text_a", "text_b", "labels"]
# Optional model configuration
model_args = ClassificationArgs(num_train_epochs=1)

model_args.save_best_model = True
model_args.learning_rate = 3e-5
model_args.train_batch_size = 8
model_args.eval_batch_size = 8
model_args.num_train_epochs =  1
model_args.regression = True
model_args.use_early_stopping = True
model_args.early_stopping_delta = 0.01
model_args.early_stopping_metric = "r2"
model_args.early_stopping_metric_minimize = False
model_args.early_stopping_patience = 5
model_args.evaluation_during_training = True
model_args.evaluate_during_training_steps = 100
model_args.overwrite_output_dir = True
model_args.evaluate_during_training = True
model_args.manual_seed = 42


model_args.overwrite_output_dir = True
model = ClassificationModel("bert", #roberta
                            "DeepPavlov/rubert-base-cased", # ai-forever/ruRoberta-large, ai-forever/sbert_large_nlu_ru,
                            num_labels=1,
                            args=model_args,
                            use_cuda=True,
                            ignore_mismatched_sizes=True,
                            )
model.train_model(train_df=train_df,
                  eval_df=eval_df,
                  mae=mean_absolute_error,
                  mse=mean_squared_error,
                  r2=r2_score,

                  )

# %%
model = RepresentationModel("bert", #roberta
                            "DeepPavlov/rubert-base-cased", # ai-forever/ruRoberta-large, ai-forever/sbert_large_nlu_ru,
                            num_labels=1,
                            args=model_args,
                            use_cuda=True,
                            ignore_mismatched_sizes=True)

# %%
train_sents_embs = model.encode_sentences(train_sents, combine_strategy="mean")
test_sents_embs = model.encode_sentences(test_sents, combine_strategy="mean")

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
                 pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], xaaxis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(test_sents_embs[:len(test_sents_embs) // 2]),
                 pd.DataFrame(test_sents_embs[len(test_sents_embs) // 2:])], axis=1)

# %%
all_regs = get_all_regressors_sklearn()

# %%
#nusvr, poisson - лучшие результаты
for reg in all_regs:
    try:
        reg.fit(train_sents_embs_df, y_train)
        print(type(reg), reg.score(test_sents_embs_df, y_test))
    except Exception:
        print(type(reg), 'no')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# corpus = [
#     'This is the first document.',
#     'This document is the second document.',
#     'And this is the third one.',
#     'Is this the first document?',
# ]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train_sents)
vectorizer.get_feature_names_out()
print(X.shape)
# Out:
# (20842, 46010)

# %%
X_test = vectorizer.transform(test_sents)

# %%
X_train_arr = X.toarray()

# %%
X_test_arr = X_test.toarray()

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(X_train_arr[:len(X_train_arr) // 2]),
                 pd.DataFrame(X_train_arr[len(X_train_arr) // 2:])], axis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(X_test_arr[:len(X_test_arr) // 2]),
                 pd.DataFrame(X_test_arr[len(X_test_arr) // 2:])], axis=1)

# %%
#nusvr, poisson - лучшие результаты
for reg in tqdm(all_regs):
    try:
        reg.fit(train_sents_embs_df, y_train)
        print(type(reg), reg.score(test_sents_embs_df, y_test))
    except Exception as E:
        print(type(reg), 'no')
        print(E)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<?, ?it/s]
# <class 'sklearn.linear_model._bayes.ARDRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._bayes.BayesianRidge'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# name 'y_train' is not defined
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.dummy.DummyRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> no
# name 'y_train' is not defined
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._huber.HuberRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.isotonic.IsotonicRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.kernel_ridge.KernelRidge'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.Lars'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LarsCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLars'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._base.LinearRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.LinearSVR'> no
# name 'y_train' is not defined
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.NuSVR'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ridge.Ridge'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ridge.RidgeCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.SVR'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._theil_sen.TheilSenRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.compose._target.TransformedTargetRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.TweedieRegressor'> no
# name 'y_train' is not defined

# %%
# !pip install tensorflow-hub
import tensorflow as tf
import tensorflow_hub as tf_hub
# Out:
# Requirement already satisfied: tensorflow-hub in /Users/gd/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: numpy>=1.12.0 in /Users/gd/lib/python3.10/site-packages (from tensorflow-hub) (1.25.2)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/gd/lib/python3.10/site-packages (from tensorflow-hub) (3.20.3)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
elmo = tf.compat.v1.Module("/Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/models/196/model.hdf5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 elmo = tf.compat.v1.Module("/Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/models/196/model.hdf5")
#
# File ~/lib/python3.10/site-packages/tensorflow/python/module/module.py:112, in Module.__init__(self, name)
#     110 else:
#     111   if not valid_identifier(name):
# --> 112     raise ValueError(
#     113         "%r is not a valid module name. Module names must be valid Python "
#     114         "identifiers (e.g. a valid class name)." % name)
#     116 self._name = name
#     117 if tf2.enabled():
#
# ValueError: '/Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/models/196/model.hdf5' is not a valid module name. Module names must be valid Python identifiers (e.g. a valid class name).

# %%
elmo = tf_hub.Module("./models/196")
embeddings = elmo(
    ["the cat is on the mat", "dogs are in the fog"],
    signature="default",
    as_dict=True)["elmo"]
embeddings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 elmo = tf_hub.Module("./models/196")
#       2 embeddings = elmo(
#       3     ["the cat is on the mat", "dogs are in the fog"],
#       4     signature="default",
#       5     as_dict=True)["elmo"]
#       6 embeddings
#
# AttributeError: module 'tensorflow_hub' has no attribute 'Module'

# %%
# !pip install --upgrade simple_elmo
# Out:
# Collecting simple_elmo
#   Downloading simple_elmo-0.9.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: h5py in /Users/gd/lib/python3.10/site-packages (from simple_elmo) (3.8.0)
# Requirement already satisfied: numpy in /Users/gd/lib/python3.10/site-packages (from simple_elmo) (1.25.2)
# Requirement already satisfied: smart-open>1.8.1 in /Users/gd/lib/python3.10/site-packages (from simple_elmo) (6.3.0)
# Requirement already satisfied: pandas in /Users/gd/lib/python3.10/site-packages (from simple_elmo) (2.1.3)
# Requirement already satisfied: scipy in /Users/gd/lib/python3.10/site-packages (from simple_elmo) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gd/lib/python3.10/site-packages (from pandas->simple_elmo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/gd/lib/python3.10/site-packages (from pandas->simple_elmo) (2023.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gd/lib/python3.10/site-packages (from pandas->simple_elmo) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/gd/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->simple_elmo) (1.16.0)
# Downloading simple_elmo-0.9.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 295.7 kB/s eta 0:00:00a 0:00:01
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: simple_elmo
# Successfully installed simple_elmo-0.9.2
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from simple_elmo import ElmoModel

model = ElmoModel()
# Out:
# 2024-03-06 10:33:57.223456: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import nltk

# %%
model.load("/Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/models/196/",)
# Out:
# 2024-03-06 10:34:00,454 : INFO : Loading model from /Users/gd/Desktop/vkr+tech_prac/VKR-Tech.Practice/models/196/...
# 2024-03-06 10:34:00,457 : INFO : We will cache the vocabulary of 100 tokens.
# 'The model is now loaded.'

# %%
train_sents_ = []
test_sents_ = []

for s in train_sents:
    train_sents_.append([w for w in nltk.word_tokenize(s) if w not in string.punctuation])

for s in test_sents:
    test_sents_.append([w for w in nltk.word_tokenize(s) if w not in string.punctuation])

# %%
len(train_sents_)
# Out:
# 20842

# %%
train_sents_embs = model.get_elmo_vector_average(train_sents_, )
test_sents_embs = model.get_elmo_vector_average(test_sents_)
# Out:
# 2024-03-06 13:29:18,354 : INFO : Warming up ELMo on 32 sentences...
# 2024-03-06 13:29:19,840 : INFO : Warming up finished.
# 2024-03-06 13:29:19,844 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:20,829 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:21,845 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:22,943 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:23,781 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:24,789 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:26,496 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:27,667 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:29,473 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:30,494 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:31,884 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:32,882 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:33,808 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:35,282 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:36,579 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:37,874 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:39,692 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:41,075 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:42,250 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:43,388 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:44,453 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:45,444 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:46,822 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:47,975 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:50,025 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:51,353 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:52,817 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:53,891 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:54,835 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:55,817 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:56,738 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:57,822 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:58,840 : INFO : Texts in the current batch: 32
# 2024-03-06 13:29:59,953 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:01,142 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:01,949 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:03,558 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:04,773 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:06,146 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:07,745 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:09,277 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:10,842 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:12,003 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:13,271 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:14,166 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:16,148 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:17,149 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:18,645 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:19,596 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:20,787 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:21,861 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:23,052 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:24,641 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:25,779 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:27,408 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:28,881 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:30,869 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:32,223 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:33,180 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:33,939 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:34,888 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:37,181 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:38,552 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:39,697 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:40,705 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:43,270 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:44,636 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:45,935 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:47,365 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:48,443 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:49,651 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:50,434 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:51,771 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:52,950 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:54,077 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:55,134 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:56,112 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:57,072 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:58,115 : INFO : Texts in the current batch: 32
# 2024-03-06 13:30:59,681 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:01,362 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:02,321 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:03,629 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:05,794 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:07,197 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:08,877 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:09,808 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:11,080 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:12,257 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:13,313 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:14,602 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:15,625 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:16,716 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:17,797 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:18,993 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:20,340 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:21,334 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:22,276 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:23,388 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:24,520 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:25,491 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:27,104 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:28,182 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:30,990 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:32,149 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:33,259 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:34,284 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:36,492 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:37,451 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:38,847 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:39,837 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:41,266 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:42,351 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:43,483 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:44,744 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:45,714 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:47,017 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:48,009 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:49,090 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:50,192 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:51,217 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:52,255 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:53,523 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:54,731 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:55,809 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:56,839 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:57,855 : INFO : Texts in the current batch: 32
# 2024-03-06 13:31:59,182 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:00,309 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:01,317 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:02,233 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:03,334 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:04,401 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:06,094 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:07,268 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:08,570 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:09,701 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:10,808 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:11,936 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:12,851 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:13,674 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:14,899 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:16,300 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:17,510 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:18,759 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:19,626 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:20,786 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:21,765 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:22,485 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:23,554 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:24,379 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:25,618 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:26,828 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:27,837 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:28,905 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:29,850 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:30,927 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:32,427 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:33,568 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:34,676 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:35,869 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:37,293 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:39,418 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:41,320 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:42,847 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:43,908 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:45,172 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:46,047 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:47,073 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:48,063 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:49,141 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:51,093 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:51,986 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:53,058 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:54,003 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:54,942 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:55,907 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:56,913 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:58,233 : INFO : Texts in the current batch: 32
# 2024-03-06 13:32:59,444 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:00,488 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:01,682 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:02,757 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:03,833 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:04,710 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:05,921 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:07,067 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:08,116 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:09,190 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:10,169 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:11,295 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:12,230 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:13,965 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:15,107 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:16,510 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:17,964 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:19,220 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:20,300 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:21,749 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:22,643 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:23,663 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:25,172 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:26,579 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:27,723 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:28,724 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:32,151 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:33,301 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:35,096 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:36,290 : INFO : Texts in the current batch: 32
# 2024-03-06 13:33:37,670 : INFO : Texts in the current batch: 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 train_sents_embs = model.get_elmo_vector_average(train_sents_, )
#       2 test_sents_embs = model.get_elmo_vector_average(test_sents_)
#
# File ~/lib/python3.10/site-packages/simple_elmo/elmo_helpers.py:315, in ElmoModel.get_elmo_vector_average(self, texts, warmup, layers, session)
#     312 self.logger.info(f"Texts in the current batch: {len(chunk)}")
#     314 # Compute ELMo representations.
# --> 315 elmo_vectors = sess.run(
#     316     self.elmo_sentence_input["weighted_op"],
#     317     feed_dict={self.sentence_character_ids: sentence_ids},
#     318 )
#     320 self.logger.debug(f"ELMo sentence input shape: {elmo_vectors.shape}")
#     322 if layers == "all":
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:972, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     969 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     971 try:
# --> 972   result = self._run(None, fetches, feed_dict, options_ptr,
#     973                      run_metadata_ptr)
#     974   if run_metadata:
#     975     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:1215, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1212 # We only want to really perform the run if fetches or targets are provided,
#    1213 # or if the call is a partial run that specifies feeds.
#    1214 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1215   results = self._do_run(handle, final_targets, final_fetches,
#    1216                          feed_dict_tensor, options, run_metadata)
#    1217 else:
#    1218   results = []
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:1395, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1392   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1394 if handle is None:
# -> 1395   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1396                        run_metadata)
#    1397 else:
#    1398   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:1402, in BaseSession._do_call(self, fn, *args)
#    1400 def _do_call(self, fn, *args):
#    1401   try:
# -> 1402     return fn(*args)
#    1403   except errors.OpError as e:
#    1404     message = compat.as_text(e.message)
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:1385, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1382 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1383   # Ensure any changes to the graph are reflected in the runtime.
#    1384   self._extend_graph()
# -> 1385   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1386                                   target_list, run_metadata)
#
# File ~/lib/python3.10/site-packages/tensorflow/python/client/session.py:1478, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1476 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1477                         run_metadata):
# -> 1478   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1479                                           fetch_list, target_list,
#    1480                                           run_metadata)
#
# KeyboardInterrupt:

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
                 pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], axis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(test_sents_embs[:len(test_sents_embs) // 2]),
                 pd.DataFrame(test_sents_embs[len(test_sents_embs) // 2:])], axis=1)

# %%
lr.fit(train_sents_embs_df, df_train.score)
# Out:
# LassoLarsCV()

# %%
br.fit(train_sents_embs_df, df_train.score)
# Out:
# BayesianRidge()

# %%
print(br.score(test_sents_embs_df, df_eval.score))
# Out:
# 0.13789641969716881

# %%
print(lr.score(test_sents_embs_df, df_eval.score))
# Out:
# 0.12444835040891344

# %%
mean_absolute_error(df_eval.score, br.predict(test_sents_embs_df), )
# Out:
# 0.4309160458012329

# %%
mean_absolute_error(df_eval.score, lr.predict(test_sents_embs_df), )
# Out:
# 0.4352199592127738

# %%
mean_squared_error(df_eval.score, lr.predict(test_sents_embs_df), )
# Out:
# 0.2188870909389859

# %%
mean_squared_error(df_eval.score, br.predict(test_sents_embs_df), )
# Out:
# 0.21552508623414993

# %%
#nusvr, poisson - лучшие результаты
from tqdm import tqdm
for reg in tqdm(all_regs):
    try:
        reg.fit(train_sents_embs_df, df_train.score)
        print(type(reg), reg.score(test_sents_embs_df, df_eval.score))
    except Exception as E:
        print(type(reg), 'no')
        print(E)
# Out:
#   2%|▏         | 1/49 [08:42<6:57:50, 522.30s/it]
# <class 'sklearn.linear_model._bayes.ARDRegression'> 0.10729192420920108
#   4%|▍         | 2/49 [08:48<2:51:08, 218.49s/it]
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> 0.027734280065595196
#   6%|▌         | 3/49 [11:30<2:27:57, 192.98s/it]
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> 0.0019799817939885056
#   8%|▊         | 4/49 [11:36<1:29:16, 119.04s/it]
# <class 'sklearn.linear_model._bayes.BayesianRidge'> 0.13789641969716881
#  10%|█         | 5/49 [11:36<55:53, 76.22s/it]
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
#  12%|█▏        | 6/49 [11:56<40:52, 57.05s/it]
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> -0.8380541664865282
# <class 'sklearn.dummy.DummyRegressor'> -5.842075443407424e-06
#  16%|█▋        | 8/49 [11:57<19:52, 29.07s/it]
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> -5.842075443407424e-06
#  18%|█▊        | 9/49 [19:33<1:33:37, 140.44s/it]
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> 0.12792124716265074
#  20%|██        | 10/49 [19:36<1:07:03, 103.16s/it]
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> -0.8427035446479614
#  24%|██▍       | 12/49 [24:41<1:10:19, 114.05s/it]
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> 0.08760602960038033
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  27%|██▋       | 13/49 [38:05<3:08:13, 313.72s/it]
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> 0.03643391708803312
#  29%|██▊       | 14/49 [46:52<3:39:16, 375.91s/it]
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> 0.10037602624579167
#  31%|███       | 15/49 [47:02<2:31:54, 268.07s/it]
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> 0.10053968300007388
#  35%|███▍      | 17/49 [47:25<1:13:19, 137.49s/it]
# <class 'sklearn.linear_model._huber.HuberRegressor'> 0.030275599992430013
# <class 'sklearn.isotonic.IsotonicRegression'> no
# Isotonic regression input X should be a 1d array or 2d array with 1 feature
#  37%|███▋      | 18/49 [47:27<50:03, 96.90s/it]
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> -0.06507954922108095
#  39%|███▉      | 19/49 [47:36<35:24, 70.82s/it]
# <class 'sklearn.kernel_ridge.KernelRidge'> 0.13166624359533008
#  41%|████      | 20/49 [47:38<24:17, 50.26s/it]
# <class 'sklearn.linear_model._least_angle.Lars'> -0.16586085497329495
#  43%|████▎     | 21/49 [47:49<17:58, 38.52s/it]
# <class 'sklearn.linear_model._least_angle.LarsCV'> 0.0672907974727952
#  45%|████▍     | 22/49 [47:50<12:12, 27.14s/it]
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> -5.842075443407424e-06
#  47%|████▋     | 23/49 [55:11<1:05:27, 151.07s/it]
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> 0.12504986174727262
#  49%|████▉     | 24/49 [55:12<44:11, 106.05s/it]
# <class 'sklearn.linear_model._least_angle.LassoLars'> -5.842075443407424e-06
#  51%|█████     | 25/49 [55:25<31:20, 78.34s/it]
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> 0.12444835040891344
#  53%|█████▎    | 26/49 [55:31<21:41, 56.60s/it]
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> 0.12511614793661674
#  55%|█████▌    | 27/49 [55:35<14:55, 40.70s/it]
# <class 'sklearn.linear_model._base.LinearRegression'> 0.024590033768515873
#  57%|█████▋    | 28/49 [55:41<10:39, 30.47s/it]
# <class 'sklearn.svm._classes.LinearSVR'> -0.009606114980121205
#  59%|█████▉    | 29/49 [56:46<13:37, 40.89s/it]
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> -0.3089852504881485
#  61%|██████    | 30/49 [56:47<09:05, 28.73s/it]
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# For mono-task outputs, use ElasticNet
#  63%|██████▎   | 31/49 [56:47<06:04, 20.25s/it]
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# For mono-task outputs, use ElasticNetCVCV
#  65%|██████▌   | 32/49 [56:48<04:02, 14.27s/it]
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# For mono-task outputs, use ElasticNet
#  67%|██████▋   | 33/49 [56:48<02:41, 10.08s/it]
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# For mono-task outputs, use LassoCVCV
#  69%|██████▉   | 34/49 [1:08:40<55:09, 220.61s/it]
# <class 'sklearn.svm._classes.NuSVR'> 0.10553564917261771
#  71%|███████▏  | 35/49 [1:08:41<36:07, 154.81s/it]
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> 0.09398093433682753
#  73%|███████▎  | 36/49 [1:08:54<24:18, 112.22s/it]
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> 0.09131271253491424
#  76%|███████▌  | 37/49 [1:08:54<15:44, 78.67s/it]
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
#  78%|███████▊  | 38/49 [1:08:56<10:10, 55.53s/it]
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> 0.0996764396769223
#  80%|███████▉  | 39/49 [1:08:57<06:33, 39.35s/it]
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> -2.3685867380257286
#  82%|████████▏ | 40/49 [1:08:58<04:09, 27.72s/it]
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> 0.0027628947527834624
#  84%|████████▎ | 41/49 [1:12:02<09:58, 74.75s/it]
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> -0.2354605030971879
#  86%|████████▌ | 42/49 [1:12:05<06:11, 53.03s/it]
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> -2.7831800558121e+38
#  88%|████████▊ | 43/49 [1:41:50<57:15, 572.58s/it]
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> 0.08660036910406232
#  90%|████████▉ | 44/49 [1:41:51<33:26, 401.36s/it]
# <class 'sklearn.linear_model._ridge.Ridge'> 0.1323150003176381
#  92%|█████████▏| 45/49 [1:42:02<18:56, 284.25s/it]
# <class 'sklearn.linear_model._ridge.RidgeCV'> 0.13210515365845976
#  94%|█████████▍| 46/49 [1:42:03<09:57, 199.29s/it]
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> 0.09362903598432148
#  94%|█████████▍| 46/49 [2:18:46<09:03, 181.00s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 5
#       3 for reg in tqdm(all_regs):
#       4     try:
# ----> 5         reg.fit(train_sents_embs_df, df_train.score)
#       6         print(type(reg), reg.score(test_sents_embs_df, df_eval.score))
#       7     except Exception as E:
#
# File ~/lib/python3.10/site-packages/sklearn/linear_model/_theil_sen.py:440, in TheilSenRegressor.fit(self, X, y)
#     438 n_jobs = effective_n_jobs(self.n_jobs)
#     439 index_list = np.array_split(indices, n_jobs)
# --> 440 weights = Parallel(n_jobs=n_jobs, verbose=self.verbose)(
#     441     delayed(_lstsq)(X, y, index_list[job], self.fit_intercept)
#     442     for job in range(n_jobs)
#     443 )
#     444 weights = np.vstack(weights)
#     445 self.n_iter_, coefs = _spatial_median(
#     446     weights, max_iter=self.max_iter, tol=self.tol
#     447 )
#
# File ~/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/lib/python3.10/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/lib/python3.10/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/lib/python3.10/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/lib/python3.10/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/lib/python3.10/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/lib/python3.10/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/lib/python3.10/site-packages/sklearn/linear_model/_theil_sen.py:203, in _lstsq(X, y, indices, fit_intercept)
#     201     X_subpopulation[:, fit_intercept:] = X[subset, :]
#     202     y_subpopulation[:n_subsamples] = y[subset]
# --> 203     weights[index] = lstsq(X_subpopulation, y_subpopulation)[1][:n_features]
#     205 return weights
#
# KeyboardInterrupt:

# %%
train_sents

# %%
import fastText as ft

# Loading model for Finnish.
model = ft.load_model('cc.ru.300.bin')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import fastText as ft
#       3 # Loading model for Finnish.
#       4 model = ft.load_model('cc.ru.300.bin')
#
# ModuleNotFoundError: No module named 'fastText'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
