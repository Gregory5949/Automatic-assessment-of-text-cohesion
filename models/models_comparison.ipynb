# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (24.0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\j0hn_lenin\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\j0hn_lenin\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %%
from tqdm import tqdm

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (4.3.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.18.5 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.11.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from gensim) (6.4.0)

# %%
#!pip install pyarrow
#!pip install simpletransformers
# !pip install simpletransformers==0.26.0
import string
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk import word_tokenize
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# %pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: sentence_transformers in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (4.32.0)
# Requirement already satisfied: tqdm in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.15.2)
# Requirement already satisfied: numpy in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.24.2)
# Requirement already satisfied: scikit-learn in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.11.2)
# Requirement already satisfied: nltk in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: sympy in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.8.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.3)
# Requirement already satisfied: click in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from torchvision->sentence_transformers) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\J0hn_Lenin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
df = pd.read_csv('C:\\Git\\VKR-Tech.Practice\\data\\balanced_dataset.csv')
np.random.seed(42)
msk = np.random.rand(len(df)) < 0.8
df_train = df[msk]
df_eval = df[~msk]

# %%
train_sents = []
for i in df_train.sents_l:
    train_sents.append(i)
for j in df_train.sents_r:
    train_sents.append(j)

test_sents = []
for i in df_eval.sents_l:
    test_sents.append(i)
for j in df_eval.sents_r:
    test_sents.append(j)

# %%
tagged_data = [
    TaggedDocument(words=[w.lower() for w in word_tokenize(_d) if w not in string.punctuation], tags=[str(i)]) for i, _d
    in enumerate(train_sents)]

# %%
# model50 = Doc2Vec(vector_size=50)
# model50.build_vocab(tagged_data)

# model100 = Doc2Vec(vector_size=100)
# model100.build_vocab(tagged_data)

# model150 = Doc2Vec(vector_size=150)
# model150.build_vocab(tagged_data)

# model200 = Doc2Vec(vector_size=200)
# model200.build_vocab(tagged_data)

model250 = Doc2Vec(vector_size=250)
model250.build_vocab(tagged_data)

model300 = Doc2Vec(vector_size=300)
model300.build_vocab(tagged_data)

# %%
# model50.train(tagged_data, total_examples=model50.corpus_count, epochs=model50.epochs)
# model100.train(tagged_data, total_examples=model100.corpus_count, epochs=model100.epochs)
# model150.train(tagged_data, total_examples=model150.corpus_count, epochs=model150.epochs)
# model200.train(tagged_data, total_examples=model200.corpus_count, epochs=model200.epochs)
model250.train(tagged_data, total_examples=model250.corpus_count, epochs=model250.epochs)
model300.train(tagged_data, total_examples=model300.corpus_count, epochs=model300.epochs)

# %%
# X50 = pd.concat([pd.DataFrame(model50.dv.vectors[:len(model50.dv.vectors) // 2]),
#                  pd.DataFrame(model50.dv.vectors[len(model50.dv.vectors) // 2:])], axis=1)
# X100 = pd.concat([pd.DataFrame(model100.dv.vectors[:len(model100.dv.vectors) // 2]),
#                   pd.DataFrame(model100.dv.vectors[len(model100.dv.vectors) // 2:])], axis=1)
# X150 = pd.concat([pd.DataFrame(model150.dv.vectors[:len(model150.dv.vectors) // 2]),
#                   pd.DataFrame(model150.dv.vectors[len(model150.dv.vectors) // 2:])], axis=1)
# X200 = pd.concat([pd.DataFrame(model200.dv.vectors[:len(model200.dv.vectors) // 2]),
#                   pd.DataFrame(model200.dv.vectors[len(model200.dv.vectors) // 2:])], axis=1)

# X250_train = pd.concat([pd.DataFrame(model250.dv.vectors[:len(model250.dv.vectors) // 2]),
#                   pd.DataFrame(model250.dv.vectors[len(model250.dv.vectors) // 2:])], axis=1)
# X300_train = pd.concat([pd.DataFrame(model300.dv.vectors[:len(model300.dv.vectors) // 2]),
#                   pd.DataFrame(model300.dv.vectors[len(model300.dv.vectors) // 2:])], axis=1)
y_train = df_train.score

# %%
# X50_test = []
# X100_test = []
# X150_test = []
# X200_test = []
X250_test = []
X300_test = []

for i in df_eval.sents_l:
    # X50_test.append(model50.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X100_test.append(model100.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X150_test.append(model150.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    # X200_test.append(model200.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    X250_test.append(model250.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))
    X300_test.append(model300.infer_vector([w.lower() for w in word_tokenize(i) if w not in string.punctuation]))

for j in df_eval.sents_r:
    # X50_test.append(model50.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X100_test.append(model100.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X150_test.append(model150.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    # X200_test.append(model200.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    X250_test.append(model250.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))
    X300_test.append(model300.infer_vector([w.lower() for w in word_tokenize(j) if w not in string.punctuation]))

# %%
# X50_test_df = pd.concat([pd.DataFrame(X50_test[:len(X50_test) // 2]),
#                  pd.DataFrame(X50_test[len(X50_test) // 2:])], axis=1)

# X100_test_df = pd.concat([pd.DataFrame(X100_test[:len(X100_test) // 2]),
#                  pd.DataFrame(X100_test[len(X100_test) // 2:])], axis=1)

# X150_test_df = pd.concat([pd.DataFrame(X150_test[:len(X150_test) // 2]),
#                  pd.DataFrame(X150_test[len(X150_test) // 2:])], axis=1)

# X200_test_df = pd.concat([pd.DataFrame(X200_test[:len(X200_test) // 2]),
#                  pd.DataFrame(X200_test[len(X200_test) // 2:])], axis=1)

# X250_test = pd.concat([pd.DataFrame(X250_test[:len(X250_test) // 2]),
#                  pd.DataFrame(X250_test[len(X250_test) // 2:])], axis=1)

# X300_test = pd.concat([pd.DataFrame(X300_test[:len(X300_test) // 2]),
#                  pd.DataFrame(X300_test[len(X300_test) // 2:])], axis=1)


y_test = df_eval.score

# %%
X250_train.columns = list(range(500))
X250_test.columns = list(range(500))

X300_train.columns = list(range(600))
X300_test.columns = list(range(600))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 X250_train.columns = list(range(500))
#       2 X250_test.columns = list(range(500))
#       4 X300_train.columns = list(range(600))
#
# NameError: name 'X250_train' is not defined

# %%
from sklearn.utils import all_estimators
def get_all_regressors_sklearn():
    estimators = all_estimators(type_filter='regressor')
    all_regs = []
    for name, RegClass in estimators:
        print('Appending', name)
        try:
            if name != 'QuantileRegressor':
                reg = RegClass()
                all_regs.append(reg)
        except Exception as e:
            pass
    return all_regs
all_regs = get_all_regressors_sklearn()
# Out:
# Appending ARDRegression
# Appending AdaBoostRegressor
# Appending BaggingRegressor
# Appending BayesianRidge
# Appending CCA
# Appending DecisionTreeRegressor
# Appending DummyRegressor
# Appending ElasticNet
# Appending ElasticNetCV
# Appending ExtraTreeRegressor
# Appending ExtraTreesRegressor
# Appending GammaRegressor
# Appending GaussianProcessRegressor
# Appending GradientBoostingRegressor
# Appending HistGradientBoostingRegressor
# Appending HuberRegressor
# Appending IsotonicRegression
# Appending KNeighborsRegressor
# Appending KernelRidge
# Appending Lars
# Appending LarsCV
# Appending Lasso
# Appending LassoCV
# Appending LassoLars
# Appending LassoLarsCV
# Appending LassoLarsIC
# Appending LinearRegression
# Appending LinearSVR
# Appending MLPRegressor
# Appending MultiOutputRegressor
# Appending MultiTaskElasticNet
# Appending MultiTaskElasticNetCV
# Appending MultiTaskLasso
# Appending MultiTaskLassoCV
# Appending NuSVR
# Appending OrthogonalMatchingPursuit
# Appending OrthogonalMatchingPursuitCV
# Appending PLSCanonical
# Appending PLSRegression
# Appending PassiveAggressiveRegressor
# Appending PoissonRegressor
# Appending QuantileRegressor
# Appending RANSACRegressor
# Appending RadiusNeighborsRegressor
# Appending RandomForestRegressor
# Appending RegressorChain
# Appending Ridge
# Appending RidgeCV
# Appending SGDRegressor
# Appending SVR
# Appending StackingRegressor
# Appending TheilSenRegressor
# Appending TransformedTargetRegressor
# Appending TweedieRegressor
# Appending VotingRegressor

# %%
#на dov2vec плохие результаты
for reg in all_regs:
    try:
        reg.fit(X250_train, y_train)
        print(type(reg), reg.score(X250_test, y_test))
    except Exception:
        print(type(reg), 'no')
# Out:
# <class 'sklearn.linear_model._bayes.ARDRegression'> no
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> no
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> no
# <class 'sklearn.linear_model._bayes.BayesianRidge'> no
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> no
# <class 'sklearn.dummy.DummyRegressor'> no
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> no
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> no
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> no
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> no
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> no
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> no
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> no
# <class 'sklearn.linear_model._huber.HuberRegressor'> no
# <class 'sklearn.isotonic.IsotonicRegression'> no
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> no
# <class 'sklearn.kernel_ridge.KernelRidge'> no
# <class 'sklearn.linear_model._least_angle.Lars'> no
# <class 'sklearn.linear_model._least_angle.LarsCV'> no
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> no
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> no
# <class 'sklearn.linear_model._least_angle.LassoLars'> no
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> no
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> no
# <class 'sklearn.linear_model._base.LinearRegression'> no
# <class 'sklearn.svm._classes.LinearSVR'> no
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# <class 'sklearn.svm._classes.NuSVR'> no
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> no
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> no
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> no
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> no
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> no
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> no
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> no
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> no
# <class 'sklearn.linear_model._ridge.Ridge'> no
# <class 'sklearn.linear_model._ridge.RidgeCV'> no
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> no
# <class 'sklearn.svm._classes.SVR'> no
# <class 'sklearn.linear_model._theil_sen.TheilSenRegressor'> no
# <class 'sklearn.compose._target.TransformedTargetRegressor'> no
# <class 'sklearn.linear_model._glm.glm.TweedieRegressor'> no

# %%
#nusvr, poisson - лучшие результаты
for reg in all_regs:
    try:
        reg.fit(X300_train, y_train)
        print(type(reg), reg.score(X300_test, y_test))
    except Exception:
        print(type(reg), 'no')
# Out:
# <class 'sklearn.linear_model._bayes.ARDRegression'> no
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> no
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> no
# <class 'sklearn.linear_model._bayes.BayesianRidge'> no
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> no
# <class 'sklearn.dummy.DummyRegressor'> no
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> no
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> no
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> no
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> no
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> no
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> no
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> no
# <class 'sklearn.linear_model._huber.HuberRegressor'> no
# <class 'sklearn.isotonic.IsotonicRegression'> no
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> no
# <class 'sklearn.kernel_ridge.KernelRidge'> no
# <class 'sklearn.linear_model._least_angle.Lars'> no
# <class 'sklearn.linear_model._least_angle.LarsCV'> no
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> no
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> no
# <class 'sklearn.linear_model._least_angle.LassoLars'> no
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> no
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> no
# <class 'sklearn.linear_model._base.LinearRegression'> no
# <class 'sklearn.svm._classes.LinearSVR'> no
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# <class 'sklearn.svm._classes.NuSVR'> no
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> no
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> no
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> no
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> no
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> no
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> no
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> no
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> no
# <class 'sklearn.linear_model._ridge.Ridge'> no
# <class 'sklearn.linear_model._ridge.RidgeCV'> no
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> no
# <class 'sklearn.svm._classes.SVR'> no
# <class 'sklearn.linear_model._theil_sen.TheilSenRegressor'> no
# <class 'sklearn.compose._target.TransformedTargetRegressor'> no
# <class 'sklearn.linear_model._glm.glm.TweedieRegressor'> no

# %%
sentence_transformer = SentenceTransformer("DeepPavlov/rubert-base-cased")
# Out:
# Downloading .gitattributes: 100%|██████████| 391/391 [00:00<?, ?B/s]
# Downloading README.md: 100%|██████████| 584/584 [00:00<00:00, 586kB/s]
# Downloading config.json: 100%|██████████| 642/642 [00:00<?, ?B/s]
# Downloading pytorch_model.bin: 100%|██████████| 714M/714M [00:11<00:00, 64.4MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 112/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json: 100%|██████████| 24.0/24.0 [00:00<00:00, 24.6kB/s]
# Downloading vocab.txt: 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.51MB/s]
# No sentence-transformers model found with name C:\Users\J0hn_Lenin/.cache\torch\sentence_transformers\DeepPavlov_rubert-base-cased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\J0hn_Lenin/.cache\torch\sentence_transformers\DeepPavlov_rubert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
train_sents_embs = sentence_transformer.encode(train_sents)

# %%
test_sents_embs = sentence_transformer.encode(test_sents)

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
                 pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], axis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(test_sents_embs[:len(test_sents_embs) // 2]),
                 pd.DataFrame(test_sents_embs[len(test_sents_embs) // 2:])], axis=1)

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import LassoLarsCV
br = BayesianRidge()
lr = LassoLarsCV()

# %%
lr.fit(train_sents_embs_df, y_train)
# Out:
# LassoLarsCV()

# %%
lr.score(test_sents_embs_df, y_test)
# Out:
# 0.12301876443716553

# %%
br.fit(train_sents_embs_df, y_train)
br.score(test_sents_embs_df, y_test)
# Out:
# 0.130008739013578

# %%
# %pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.70.0-py3-none-any.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.4 kB ? eta -:--:--
#      -------------------------------------- 42.4/42.4 kB 684.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (1.24.2)
# Requirement already satisfied: requests in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (2023.8.8)
# Requirement already satisfied: transformers>=4.31.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (4.32.0)
# Collecting datasets (from simpletransformers)
#   Downloading datasets-2.17.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (1.11.2)
# Requirement already satisfied: scikit-learn in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (1.3.0)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      ---------------------------------------- 43.6/43.6 kB ? eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tensorboard (from simpletransformers)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardx (from simpletransformers)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (2.0.3)
# Requirement already satisfied: tokenizers in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (0.13.3)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.16.3-py3-none-any.whl.metadata (9.9 kB)
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: sentencepiece in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from simpletransformers) (0.1.99)
# Requirement already satisfied: colorama in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.47.0->simpletransformers) (0.4.6)
# Requirement already satisfied: filelock in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.31.0->simpletransformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.31.0->simpletransformers) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.31.0->simpletransformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.31.0->simpletransformers) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.31.0->simpletransformers) (0.3.3)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from wandb>=0.10.32->simpletransformers) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\j0hn_lenin\appdata\roaming\python\python311\site-packages (from wandb>=0.10.32->simpletransformers) (5.9.8)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-1.40.5-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.3-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from wandb>=0.10.32->simpletransformers) (65.5.0)
# Collecting appdirs>=1.4.3 (from wandb>=0.10.32->simpletransformers)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->simpletransformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->simpletransformers) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from requests->simpletransformers) (2023.5.7)
# Collecting pyarrow>=12.0.0 (from datasets->simpletransformers)
#   Downloading pyarrow-15.0.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets->simpletransformers)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets->simpletransformers) (2023.6.0)
# Collecting aiohttp (from datasets->simpletransformers)
#   Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers>=4.31.0->simpletransformers)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->simpletransformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->simpletransformers) (3.2.0)
# Collecting altair<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting importlib-metadata<8,>=1.4 (from streamlit->simpletransformers)
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->simpletransformers) (9.5.0)
# Collecting rich<14,>=10.14.0 (from streamlit->simpletransformers)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit->simpletransformers)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->simpletransformers)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from streamlit->simpletransformers) (4.7.1)
# Collecting tzlocal<6,>=1.1 (from streamlit->simpletransformers)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit->simpletransformers)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\j0hn_lenin\appdata\roaming\python\python311\site-packages (from streamlit->simpletransformers) (6.4)
# Collecting watchdog>=2.1.5 (from streamlit->simpletransformers)
#   Downloading watchdog-4.0.0-py3-none-win_amd64.whl.metadata (37 kB)
# Collecting absl-py>=0.4 (from tensorboard->simpletransformers)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->simpletransformers)
#   Downloading grpcio-1.62.0-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting markdown>=2.6.8 (from tensorboard->simpletransformers)
#   Downloading Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: six>1.9 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from tensorboard->simpletransformers) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->simpletransformers)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->simpletransformers)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: jinja2 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.2)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=0.5 (from importlib-metadata<8,>=1.4->streamlit->simpletransformers)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->simpletransformers)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\j0hn_lenin\appdata\roaming\python\python311\site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\j0hn_lenin\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading referencing-0.33.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading simpletransformers-0.70.0-py3-none-any.whl (315 kB)
#    ---------------------------------------- 0.0/315.5 kB ? eta -:--:--
#    -------------- ------------------------- 112.6/315.5 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 315.5/315.5 kB 3.9 MB/s eta 0:00:00
# Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 10.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 17.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 15.4 MB/s eta 0:00:00
# Downloading datasets-2.17.1-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.7 kB ? eta -:--:--
#    --------------------------------------- 536.7/536.7 kB 35.1 MB/s eta 0:00:00
# Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.4 MB 67.4 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.4 MB 58.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.1/8.4 MB 41.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.7/8.4 MB 36.5 MB/s eta 0:00:01
#    ------------------------------ --------- 6.4/8.4 MB 34.2 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 33.4 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 33.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 28.2 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------------------------- ------------ 3.7/5.5 MB 78.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 58.3 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.7 kB ? eta -:--:--
#    ---------------------------------------- 133.7/133.7 kB 8.2 MB/s eta 0:00:00
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ---------------------------------------- 0.0/996.9 kB ? eta -:--:--
#    --------------------------------------- 996.9/996.9 kB 61.7 MB/s eta 0:00:00
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 365.3/365.3 kB ? eta 0:00:00
# Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#    ---------------------------------------- 0.0/195.4 kB ? eta -:--:--
#    --------------------------------------- 195.4/195.4 kB 12.3 MB/s eta 0:00:00
# Downloading grpcio-1.62.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------  3.8/3.8 MB 117.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 60.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#    ---------------------------------------- 0.0/330.1 kB ? eta -:--:--
#    --------------------------------------- 330.1/330.1 kB 20.0 MB/s eta 0:00:00
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.9 kB ? eta -:--:--
#    ---------------------------------------- 103.9/103.9 kB ? eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Downloading pyarrow-15.0.0-cp311-cp311-win_amd64.whl (24.8 MB)
#    ---------------------------------------- 0.0/24.8 MB ? eta -:--:--
#    ------ --------------------------------- 4.3/24.8 MB 91.7 MB/s eta 0:00:01
#    ------------- -------------------------- 8.1/24.8 MB 103.8 MB/s eta 0:00:01
#    -------------------- ------------------- 12.6/24.8 MB 93.9 MB/s eta 0:00:01
#    -------------------------- ------------- 16.2/24.8 MB 93.9 MB/s eta 0:00:01
#    --------------------------------- ------ 20.7/24.8 MB 110.0 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/24.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  24.8/24.8 MB 93.0 MB/s eta 0:00:01
#    ---------------------------------------  24.8/24.8 MB 93.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.8/24.8 MB 50.1 MB/s eta 0:00:00
# Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    ------------------------------ --------- 3.6/4.8 MB 117.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.8/4.8 MB 76.0 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.6 kB ? eta -:--:--
#    --------------------------------------- 240.6/240.6 kB 14.4 MB/s eta 0:00:00
# Downloading sentry_sdk-1.40.5-py2.py3-none-any.whl (258 kB)
#    ---------------------------------------- 0.0/258.5 kB ? eta -:--:--
#    ---------------------------------------- 258.5/258.5 kB ? eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading watchdog-4.0.0-py3-none-win_amd64.whl (82 kB)
#    ---------------------------------------- 0.0/82.9 kB ? eta -:--:--
#    ---------------------------------------- 82.9/82.9 kB ? eta 0:00:00
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    --------------------------------------- 226.7/226.7 kB 13.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    ---------------------------------------- 143.5/143.5 kB ? eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading setproctitle-1.3.3-cp311-cp311-win_amd64.whl (11 kB)
# Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl (29 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB ? eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB ? eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl (28 kB)
# Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.7 kB ? eta -:--:--
#    ---------------------------------------- 76.7/76.7 kB 4.2 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.33.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.7 kB ? eta -:--:--
#    --------------------------------------- 206.7/206.7 kB 12.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (pyproject.toml): started
#   Building wheel for seqeval (pyproject.toml): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16185 sha256=2a9e45a74858440d0721e2905571a04bd81144eda7c09b2842ae41cc60dbeb23
#   Stored in directory: c:\users\j0hn_lenin\appdata\local\pip\cache\wheels\bc\92\f0\243288f899c2eacdfa8c5f9aede4c71a9bad0ee26a01dc5ead
# Successfully built seqeval
# Installing collected packages: appdirs, zipp, xxhash, werkzeug, watchdog, validators, tzlocal, toolz, toml, tensorboard-data-server, tenacity, smmap, setproctitle, sentry-sdk, rpds-py, pyarrow-hotfix, pyarrow, protobuf, multidict, mdurl, markdown, grpcio, frozenlist, docker-pycreds, dill, cachetools, blinker, absl-py, yarl, tensorboardx, tensorboard, referencing, pydeck, multiprocess, markdown-it-py, importlib-metadata, huggingface-hub, gitdb, aiosignal, seqeval, rich, jsonschema-specifications, GitPython, aiohttp, wandb, jsonschema, datasets, altair, streamlit, simpletransformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.16.4
#     Uninstalling huggingface-hub-0.16.4:
#       Successfully uninstalled huggingface-hub-0.16.4
# Successfully installed GitPython-3.1.42 absl-py-2.1.0 aiohttp-3.9.3 aiosignal-1.3.1 altair-5.2.0 appdirs-1.4.4 blinker-1.7.0 cachetools-5.3.2 datasets-2.17.1 dill-0.3.8 docker-pycreds-0.4.0 frozenlist-1.4.1 gitdb-4.0.11 grpcio-1.62.0 huggingface-hub-0.20.3 importlib-metadata-7.0.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 markdown-3.5.2 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.0.5 multiprocess-0.70.16 protobuf-4.25.3 pyarrow-15.0.0 pyarrow-hotfix-0.6 pydeck-0.8.1b0 referencing-0.33.0 rich-13.7.0 rpds-py-0.18.0 sentry-sdk-1.40.5 seqeval-1.2.2 setproctitle-1.3.3 simpletransformers-0.70.0 smmap-5.0.1 streamlit-1.31.1 tenacity-8.2.3 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 toml-0.10.2 toolz-0.12.1 tzlocal-5.2 validators-0.22.0 wandb-0.16.3 watchdog-4.0.0 werkzeug-3.0.1 xxhash-3.4.1 yarl-1.9.4 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
from simpletransformers.classification import ClassificationModel, ClassificationArgs
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

train_df = pd.DataFrame(df_train)
train_df.columns = ["text_a", "text_b", "labels"]

eval_df = pd.DataFrame(df_eval)
eval_df.columns = ["text_a", "text_b", "labels"]
# Optional model configuration
model_args = ClassificationArgs(num_train_epochs=1)

model_args.save_best_model = True
model_args.learning_rate = 3e-5
model_args.train_batch_size = 8
model_args.eval_batch_size = 8
model_args.num_train_epochs =  1
model_args.regression = True
model_args.use_early_stopping = True
model_args.early_stopping_delta = 0.01
model_args.early_stopping_metric = "r2"
model_args.early_stopping_metric_minimize = False
model_args.early_stopping_patience = 5
model_args.evaluation_during_training = True
model_args.evaluate_during_training_steps = 100
model_args.overwrite_output_dir = True
model_args.evaluate_during_training = True
model_args.manual_seed = 42


model_args.overwrite_output_dir = True
model = ClassificationModel("bert", #roberta
                            "DeepPavlov/rubert-base-cased", # ai-forever/ruRoberta-large, ai-forever/sbert_large_nlu_ru,
                            num_labels=1,
                            args=model_args,
                            use_cuda=True,
                            ignore_mismatched_sizes=True,
                            )
model.train_model(train_df=train_df,
                  eval_df=eval_df,
                  mae=mean_absolute_error,
                  mse=mean_squared_error,
                  r2=r2_score,

                  )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 2
#       1 import logging
# ----> 2 from simpletransformers.classification import ClassificationModel, ClassificationArgs
#       3 logging.basicConfig(level=logging.INFO)
#       4 transformers_logger = logging.getLogger("transformers")
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpletransformers\classification\__init__.py:1
# ----> 1 from simpletransformers.classification.classification_model import ClassificationModel
#       2 from simpletransformers.classification.multi_label_classification_model import (
#       3     MultiLabelClassificationModel,
#       4 )
#       5 from simpletransformers.classification.multi_modal_classification_model import (
#       6     MultiModalClassificationModel,
#       7 )
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpletransformers\classification\classification_model.py:123
#      50 from transformers import (
#      51     AlbertConfig,
#      52     AlbertTokenizer,
#    (...)
#     119     XLNetForSequenceClassification,
#     120 )
#     121 from transformers.convert_graph_to_onnx import convert, quantize
# --> 123 from simpletransformers.classification.classification_utils import (
#     124     InputExample,
#     125     LazyClassificationDataset,
#     126     ClassificationDataset,
#     127     convert_examples_to_features,
#     128     load_hf_dataset,
#     129     flatten_results,
#     130 )
#     131 from simpletransformers.config.global_args import global_args
#     132 from simpletransformers.config.model_args import ClassificationArgs
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpletransformers\classification\classification_utils.py:40
#      37 from sklearn.metrics import f1_score, matthews_corrcoef
#      39 from torch.utils.data import Dataset
# ---> 40 from datasets import load_dataset
#      41 from datasets import Dataset as HFDataset
#      42 from tqdm.auto import tqdm
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\__init__.py:18
#       1 # ruff: noqa
#       2 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 __version__ = "2.17.1"
# ---> 18 from .arrow_dataset import Dataset
#      19 from .arrow_reader import ReadInstruction
#      20 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\arrow_dataset.py:69
#      67 from .arrow_reader import ArrowReader
#      68 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
# ---> 69 from .data_files import sanitize_patterns
#      70 from .download.streaming_download_manager import xgetsize
#      71 from .features import Audio, ClassLabel, Features, Image, Sequence, Value
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\data_files.py:11
#       9 from fsspec import get_fs_token_paths
#      10 from fsspec.implementations.http import HTTPFileSystem
# ---> 11 from huggingface_hub import HfFileSystem
#      12 from packaging import version
#      13 from tqdm.contrib.concurrent import thread_map
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\__init__.py:322, in __getattr__(name)
#     313 def _attach(package_name, submodules=None, submod_attrs=None):
#     314     """Attach lazily loaded submodules, functions, or other attributes.
#     315
#     316     Typically, modules import submodules and attributes as follows:
#     317
#     318     ```py
#     319     import mysubmodule
#     320     import anothersubmodule
#     321
# --> 322     from .foo import someattr
#     323     ```
#     324
#     325     The idea is to replace a package's `__getattr__`, `__dir__`, and
#     326     `__all__`, such that all imports work exactly the way they would
#     327     with normal imports, except that the import occurs upon first use.
#     328
#     329     The typical way to call this function, replacing the above imports, is:
#     330
#     331     ```python
#     332     __getattr__, __dir__, __all__ = lazy.attach(
#     333         __name__,
#     334         ['mysubmodule', 'anothersubmodule'],
#     335         {'foo': ['someattr']}
#     336     )
#     337     ```
#     338     This functionality requires Python 3.7 or higher.
#     339
#     340     Args:
#     341         package_name (`str`):
#     342             Typically use `__name__`.
#     343         submodules (`set`):
#     344             List of submodules to attach.
#     345         submod_attrs (`dict`):
#     346             Dictionary of submodule -> list of attributes / functions.
#     347             These attributes are imported as they are used.
#     348
#     349     Returns:
#     350         __getattr__, __dir__, __all__
#     351
#     352     """
#     353     if submod_attrs is None:
#     354         submod_attrs = {}
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\hf_file_system.py:17
#      15 from .constants import DEFAULT_REVISION, ENDPOINT, REPO_TYPE_MODEL, REPO_TYPES_MAPPING, REPO_TYPES_URL_PREFIXES
#      16 from .file_download import hf_hub_url
# ---> 17 from .hf_api import HfApi, LastCommitInfo, RepoFile
#      18 from .utils import (
#      19     EntryNotFoundError,
#      20     HFValidationError,
#    (...)
#      24     http_backoff,
#      25 )
#      28 # Regex used to match special revisions with "/" in them (see #1710)
#
# ImportError: cannot import name 'LastCommitInfo' from 'huggingface_hub.hf_api' (c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\hf_api.py)

# %%
model = RepresentationModel("bert", #roberta
                            "DeepPavlov/rubert-base-cased", # ai-forever/ruRoberta-large, ai-forever/sbert_large_nlu_ru,
                            num_labels=1,
                            args=model_args,
                            use_cuda=True,
                            ignore_mismatched_sizes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 model = RepresentationModel("bert", #roberta
#       2                             "DeepPavlov/rubert-base-cased", # ai-forever/ruRoberta-large, ai-forever/sbert_large_nlu_ru,
#       3                             num_labels=1,
#       4                             args=model_args,
#       5                             use_cuda=True,
#       6                             ignore_mismatched_sizes=True)
#
# NameError: name 'RepresentationModel' is not defined

# %%
train_sents_embs = model.encode_sentences(train_sents, combine_strategy="mean")
test_sents_embs = model.encode_sentences(test_sents, combine_strategy="mean")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 train_sents_embs = model.encode_sentences(train_sents, combine_strategy="mean")
#       2 test_sents_embs = model.encode_sentences(test_sents, combine_strategy="mean")
#
# NameError: name 'model' is not defined

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
                 pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], xaaxis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 train_sents_embs_df = pd.concat([pd.DataFrame(train_sents_embs[:len(train_sents_embs) // 2]),
#       2                  pd.DataFrame(train_sents_embs[len(train_sents_embs) // 2:])], xaaxis=1)
#
# TypeError: concat() got an unexpected keyword argument 'xaaxis'

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(test_sents_embs[:len(test_sents_embs) // 2]),
                 pd.DataFrame(test_sents_embs[len(test_sents_embs) // 2:])], axis=1)

# %%
all_regs = get_all_regressors_sklearn()
# Out:
# Appending ARDRegression
# Appending AdaBoostRegressor
# Appending BaggingRegressor
# Appending BayesianRidge
# Appending CCA
# Appending DecisionTreeRegressor
# Appending DummyRegressor
# Appending ElasticNet
# Appending ElasticNetCV
# Appending ExtraTreeRegressor
# Appending ExtraTreesRegressor
# Appending GammaRegressor
# Appending GaussianProcessRegressor
# Appending GradientBoostingRegressor
# Appending HistGradientBoostingRegressor
# Appending HuberRegressor
# Appending IsotonicRegression
# Appending KNeighborsRegressor
# Appending KernelRidge
# Appending Lars
# Appending LarsCV
# Appending Lasso
# Appending LassoCV
# Appending LassoLars
# Appending LassoLarsCV
# Appending LassoLarsIC
# Appending LinearRegression
# Appending LinearSVR
# Appending MLPRegressor
# Appending MultiOutputRegressor
# Appending MultiTaskElasticNet
# Appending MultiTaskElasticNetCV
# Appending MultiTaskLasso
# Appending MultiTaskLassoCV
# Appending NuSVR
# Appending OrthogonalMatchingPursuit
# Appending OrthogonalMatchingPursuitCV
# Appending PLSCanonical
# Appending PLSRegression
# Appending PassiveAggressiveRegressor
# Appending PoissonRegressor
# Appending QuantileRegressor
# Appending RANSACRegressor
# Appending RadiusNeighborsRegressor
# Appending RandomForestRegressor
# Appending RegressorChain
# Appending Ridge
# Appending RidgeCV
# Appending SGDRegressor
# Appending SVR
# Appending StackingRegressor
# Appending TheilSenRegressor
# Appending TransformedTargetRegressor
# Appending TweedieRegressor
# Appending VotingRegressor

# %%
#nusvr, poisson - лучшие результаты
for reg in all_regs:
    try:
        reg.fit(train_sents_embs_df, y_train)
        print(type(reg), reg.score(test_sents_embs_df, y_test))
    except Exception:
        print(type(reg), 'no')
# Out:
# <class 'sklearn.linear_model._bayes.ARDRegression'> 0.10764092878433851
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> 0.01578452733200908
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> 0.002212450702060109
# <class 'sklearn.linear_model._bayes.BayesianRidge'> 0.130008739013578
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> -0.8194566538407961
# <class 'sklearn.dummy.DummyRegressor'> -5.842075443407424e-06
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> -5.8421575621636634e-06
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> 0.1231792192370953
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> -0.8272056174431845
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> 0.0864456997905586
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> -0.9961330239746709
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> 0.0911629034455762
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> 0.08876548110850213
# <class 'sklearn.linear_model._huber.HuberRegressor'> -0.0018953194995516842
# <class 'sklearn.isotonic.IsotonicRegression'> no
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> -0.12155399595528737
# <class 'sklearn.kernel_ridge.KernelRidge'> 0.05000445703801715
# <class 'sklearn.linear_model._least_angle.Lars'> 0.000511562868113602
# <class 'sklearn.linear_model._least_angle.LarsCV'> 0.09076544831420785
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> -5.8421575621636634e-06
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> 0.12297399201918635
# <class 'sklearn.linear_model._least_angle.LassoLars'> -5.8421575621636634e-06
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> 0.12301876443716553
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> 0.12305728091446677
# <class 'sklearn.linear_model._base.LinearRegression'> 0.04405726185270453
# <class 'sklearn.svm._classes.LinearSVR'> -0.17166043755955296
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> -0.27357168456911984
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# <class 'sklearn.svm._classes.NuSVR'> 0.0954494392898031
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> 0.09941971257147586
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> 0.09818300733725016
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> 0.10855889003488339
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> -0.2322805985328973
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> 0.053661877750625475
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> -0.2735519843569878
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> -0.9961330239752517
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> 0.0802914728975418
# <class 'sklearn.linear_model._ridge.Ridge'> 0.050031688171104594
# <class 'sklearn.linear_model._ridge.RidgeCV'> 0.07953213666724546
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> 0.09847741777875008
# <class 'sklearn.svm._classes.SVR'> 0.08626016135767278
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 4
#       2 for reg in all_regs:
#       3     try:
# ----> 4         reg.fit(train_sents_embs_df, y_train)
#       5         print(type(reg), reg.score(test_sents_embs_df, y_test))
#       6     except Exception:
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_theil_sen.py:440, in TheilSenRegressor.fit(self, X, y)
#     438 n_jobs = effective_n_jobs(self.n_jobs)
#     439 index_list = np.array_split(indices, n_jobs)
# --> 440 weights = Parallel(n_jobs=n_jobs, verbose=self.verbose)(
#     441     delayed(_lstsq)(X, y, index_list[job], self.fit_intercept)
#     442     for job in range(n_jobs)
#     443 )
#     444 weights = np.vstack(weights)
#     445 self.n_iter_, coefs = _spatial_median(
#     446     weights, max_iter=self.max_iter, tol=self.tol
#     447 )
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\J0hn_Lenin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_theil_sen.py:203, in _lstsq(X, y, indices, fit_intercept)
#     201     X_subpopulation[:, fit_intercept:] = X[subset, :]
#     202     y_subpopulation[:n_subsamples] = y[subset]
# --> 203     weights[index] = lstsq(X_subpopulation, y_subpopulation)[1][:n_features]
#     205 return weights
#
# KeyboardInterrupt:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# corpus = [
#     'This is the first document.',
#     'This document is the second document.',
#     'And this is the third one.',
#     'Is this the first document?',
# ]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train_sents)
vectorizer.get_feature_names_out()
print(X.shape)

# %%
X_test = vectorizer.transform(test_sents)

# %%
X_train_arr = X.toarray()

# %%
X_test_arr = X_test.toarray()

# %%
train_sents_embs_df = pd.concat([pd.DataFrame(X_train_arr[:len(X_train_arr) // 2]),
                 pd.DataFrame(X_train_arr[len(X_train_arr) // 2:])], axis=1)

# %%
test_sents_embs_df = pd.concat([pd.DataFrame(X_test_arr[:len(X_test_arr) // 2]),
                 pd.DataFrame(X_test_arr[len(X_test_arr) // 2:])], axis=1)

# %%
#nusvr, poisson - лучшие результаты
for reg in tqdm(all_regs):
    try:
        reg.fit(train_sents_embs_df, y_train)
        print(type(reg), reg.score(test_sents_embs_df, y_test))
    except Exception as E:
        print(type(reg), 'no')
        print(E)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<?, ?it/s]
# <class 'sklearn.linear_model._bayes.ARDRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._bagging.BaggingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._bayes.BayesianRidge'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.CCA'> no
# name 'y_train' is not defined
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.dummy.DummyRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.ElasticNet'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.ElasticNetCV'> no
# name 'y_train' is not defined
# <class 'sklearn.tree._classes.ExtraTreeRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.GammaRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.gaussian_process._gpr.GaussianProcessRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._huber.HuberRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.isotonic.IsotonicRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.kernel_ridge.KernelRidge'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.Lars'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LarsCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLars'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLarsCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._least_angle.LassoLarsIC'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._base.LinearRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.LinearSVR'> no
# name 'y_train' is not defined
# <class 'sklearn.neural_network._multilayer_perceptron.MLPRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNet'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskElasticNetCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLasso'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._coordinate_descent.MultiTaskLassoCV'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.NuSVR'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuit'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._omp.OrthogonalMatchingPursuitCV'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.PLSCanonical'> no
# name 'y_train' is not defined
# <class 'sklearn.cross_decomposition._pls.PLSRegression'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.PoissonRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ransac.RANSACRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.neighbors._regression.RadiusNeighborsRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ridge.Ridge'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._ridge.RidgeCV'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._stochastic_gradient.SGDRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.svm._classes.SVR'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._theil_sen.TheilSenRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.compose._target.TransformedTargetRegressor'> no
# name 'y_train' is not defined
# <class 'sklearn.linear_model._glm.glm.TweedieRegressor'> no
# name 'y_train' is not defined
